# %%
import pandas as pd

feature_matrix    = pd.read_parquet('../data/features/feature_matrix.parquet')
broad_daily       = pd.read_parquet('../data/features/broad_daily.parquet')
opec_flags        = pd.read_parquet('../data/features/opec_flags.parquet')
disruption_flags  = pd.read_parquet('../data/features/disruption_flags.parquet')

# %%
feature_matrix.head(10)

# %%
feature_matrix.info()

# %%
feature_matrix.describe()

# %%
broad_daily.head(10)

# %%
opec_flags.head(10)

# %%
disruption_flags.head(10)
